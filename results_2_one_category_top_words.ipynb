# %%
import os
import PIL
from PIL import Image
from IPython.display import Image
from IPython.display import Image, display

# Load plots from folder.
base_path = os.getcwd() + '/plots/one_category_top_words/'
file_names = [ base_path+f for f in os.listdir(base_path) if not '.ipynb' in f]

# Sort plots in order.
files_with_n = []
for f in file_names:
    n = f.split('/')[-1].split('_')[0]
    n = int(n)
    files_with_n.append( (n,f) )
files_sorted = sorted(files_with_n, key=lambda tup: tup[0])

print('Showing top words for {} categories:\n\n\n'.format(len(files_sorted)))
show_N = 18 # all
for i, f in files_sorted:
    if i > show_N:
        break
    name = f.split('/')[-1].split('_')[1].split('.')[0]
    print('{}. {}'.format(i, name))
    display(Image(filename=f))
# Out:
# Showing top words for 18 categories:
#
#
#
# 0. Positive
# 1. Behavioral genetics
# 2. Cultural
# 3. Quantitative
# 4. Developmental
# 5. Mathematical
# 6. Biological
# 7. Cross-cultural
# 8. Experimental
# 9. Comperative
# 10. Social
# 11. Neuropsychology
# 12. Cognitive
# 13. Evolutionary
# 14. Personality
# 15. Big Five
# 16. Cognitivism
# 17. Differential
